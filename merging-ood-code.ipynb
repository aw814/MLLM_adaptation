# %%
# Cluster version: all dependencies should be installed in your virtualenv / conda env.
# No in-notebook pip installs needed here.
import os, re  # keep imports if you need them later

# %%
# ============================================================
# Imports & basic config
# ============================================================
import os, json, glob, math, random, shutil, time
from pathlib import Path
from typing import List, Dict, Tuple
from collections import defaultdict

import numpy as np
import pandas as pd

import torch
from datasets import load_dataset
from huggingface_hub import snapshot_download
from scipy.spatial.distance import jensenshannon
from safetensors.torch import load_file as safe_load_file

from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
from peft.utils import set_peft_model_state_dict

# %%
from pathlib import Path

# Absolute project root on the cluster
PROJECT_ROOT = Path("/home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm")
print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm

# %%
# --------------------
# Repro & device
# --------------------
SEED = 3407
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ============================================================
# Base LM + tokenizer (also used as embedder + base baseline)
# ============================================================
BASE_MODEL_NAME = "unsloth/Meta-Llama-3.1-8B"
MAX_SEQ_LEN     = 2048
DTYPE           = None   # we'll resolve this below
LOAD_4BIT       = True

# choose a sane default dtype if not set
if DTYPE is None:
    if DEVICE == "cuda":
        # bf16 if supported, else fp16
        DTYPE = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16
    else:
        DTYPE = torch.float32

# Tokenizer
base_tokenizer = AutoTokenizer.from_pretrained(
    BASE_MODEL_NAME,
    use_fast=True,
    load_in_4bit=LOAD_4BIT,
)

if base_tokenizer.pad_token is None:
    base_tokenizer.pad_token = base_tokenizer.eos_token
base_tokenizer.padding_side = "left"
SPECIAL_IDS = set(getattr(base_tokenizer, "all_special_ids", []) or [])

# Base model (used for embeddings + baseline generation)
emb_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_NAME,
    dtype=DTYPE,
)
emb_model = emb_model.to(DEVICE).eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

DATASET_NAME = "kanwal-mehreen18/urdu-code-switch-eval"
TARGET_LANG  = "ur"
MAX_EVAL     = 170 # use complete dataset afterwards

def load_eval_texts(limit: int) -> List[str]:
    ds = load_dataset(DATASET_NAME)
    print("Available splits:", ds.keys())

    split_name = list(ds.keys())[0]
    ds_split = ds[split_name]
    if len(ds_split) > limit:
        ds_split = ds_split.shuffle(seed=SEED).select(range(limit))

    texts = [t for t in ds_split["Data_cs"] if isinstance(t, str) and t.strip()]
    return texts

eval_texts = load_eval_texts(MAX_EVAL)
print(f"[Data] Loaded {len(eval_texts)} Urdu eval texts")
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/355k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/163 [00:00<?, ? examples/s]
# Available splits: dict_keys(['train'])
# [Data] Loaded 163 Urdu eval texts

# %%
eval_texts
# Out:
# ['پلے روم میں جاؤ حینما میں العشاء بناؤں، ٹھیک ہے؟',
#  'کیا آپ جانتے ہیں کہ کچھ رواد فضاء ایک وقت میں اشہر تک فضاء میں رہتے ہیں؟ بین الاقوامی خلائی محطة (آئی ایس ایس) کے بارے میں اس ویڈیو کو دیکھیں تاکہ معلوم کریں کہ یہ کیف ہے۔ اگلا، رائد فضاء ڈیوڈ سینٹ جیکس کی یہ ویڈیو دیکھیں جو بین الاقوامی خلائی محطة سے ایک قصة پڑھ رہے ہیں۔ اپنے طفل سے کہیں کہ وہ ان کی مفض
#  'ترکی نے امریکہ کے ساتھ ساتھ روس سے بھی بڑے گہرے قریبی **علاقات** قائم کیے ہوئے ہیں۔ **تاریخ** میں اس سے **قبل** کبھی ترکی اور روس کے **علاقات** میں اتنی **قرب** نہیں دیکھی گئی۔ ترکی **وحید** **اسلامی** **دولة** تھا جو امریکی **تحالف** ’’نیٹو‘‘ کا بھی **عضو** تھا اور آج بھی نیٹو میں اپنی **عضویة** کو برقرار رکھے ہوئے ہے۔ ترکی نیٹو میں امریکی **قوات** کے بعد سب سے زیادہ **قوة عسكرية** رکھنے والے **دولة** ہے اور یہی **سبب** ہے کہ نیٹو کے **تحالف** میں شامل دیگر **دول أعضاء** ترکی کے نیٹو پر **نفوذ** کی وجہ سے **حسد** محسوس کرتے ہیں۔ ترکی پچاس کی **عقد** کے بعد **دائماً** ہی سے امریکی بلاک میں **منضم** رہا ہے چاہے یہاں پر سوشلسٹ اور بائیں بازو کی **حکومات** ہی کیوں نہ برسر اقتدار رہی ہوں۔ ترکی اور امریکہ کے **علاقات** میں اس **وقت** **فتور** آنا شروع ہوئی جب ۱۵جولائیء میں **إرهابي** **منظمة** ’’فیتو‘‘ نے ایردوان حکومت کا تختہ الٹنے کی **فاشلة** **محاولة** کی۔ ترکی اس **فاشلة** **انقلاب** کے پیچھے امریکی **سریة** سروس ’’سی آئی اے‘‘ کا **ید** ہونے اور ’’فیتو‘‘ کے **زعیم** ’’ فتح اللہ گولن‘‘ کی **دعم** کرنے پر **یقین** رکھتا ہے اور اس نے اس **سیاق** میں **جمیع** **أدلة** امریکی **مسؤولین** کے حوالے بھی کیے لیکن امریکہ کی **طرف** سے **أدلة** پر کان نہ دھرنے اور فتح اللہ گولن کو ترکی کے حوالے کرنے کے **طلب** کی کوئی **استجابة** نہ ہونے اور پھر **سابق** **رئیس** اوباما کے **عہد** میں امریکہ کی **طرف** سے ترکی کی **إرهابي** **منظمات** ’’ پی کے کے، وائی پی جی، پی',
#  'ہم سب مل کر چلیں گے، کل عام ۱۰ دسمبر کو فی جمیع العالم انسانی حقوق کا یوم عالمی منایا جاتا ہے۔ الحرب العالمیة الثانیة انسانی تاریخ کی أشد معرکة تدمیراً تھی۔ جب الحرب العالمیة الثانیة انتهت تو فی ذلک الوقت البشریة مجروحة تھی۔ من هذه الحرب انسانی معاشرے پر عبرتناک حد تک آثار مرتب ہوئے، التی ہنوز یاد کر کہ جسم یرتجف اٹھتا ہے۔ ملایین البشر اپنی حیات سے ہاتھ دھو بیٹھے، الظلم و العنف، القتل و السلب کا سما بلغ أقصاه تک پہنچ چکا تھا۔ اسی مابین میں الأمم المتحدة کا وجود عمل میں آیا۔ بعد ذلک ۱۰ دسمبر کو الدول الأعضاء فی الأمم المتحدة نے الإعلان العالمی لحقوق الإنسان کی متفقہ طور پر منظوری کا تاریخی إنجاز سر انجام دیا۔ و فقاً لہ ہر إنسان کو کل أنواع الحریة میسر ہوگی، اور جمیع العالم کو مساواة کے مطابق الحاجات الأساسیة اور التسهیلات کا مستحق
۔ نومبر میں الصادرة تیسری حلقة میں بھی، پہلی دونوں حلقات کی مثل، تین أغاني دی گئی ہیں۔ کوک اسٹوڈیو کے 12 ویں سیزن کا آغاز، الشهر الماضي، 11 اکتوبر کو عاطف اسلم کے "وہی خدا" سے ہوا تھا اور الآن، تیسری حلقة میں ایک مرۃ أخرى عاطف اسلم پیش ہوئے ہیں۔ کوک اسٹوڈیو 12 کی پہلی حلقة کو الشهر الماضي 19 اکتوبر کو إصدار کیا گیا تھا۔ پہلی حلقة میں تین أغاني دی گئی تھیں، مع ذلک، سب سے زیادہ سرائیکی أغنية "ماہی دیاں جھوکاں" کو الإعجاب حاصل ہوا تھا۔ پہلی حلقة کی أغنية "ماہی دیاں جھوکاں" کو جمال فقیر تروپ اور ان کے رفقاء نے تقلیدی أسلوب میں پیش کیا تھا۔ پہلی حلقة کی أغنية "دم مستم" کو راحت فتح علی خان نے، بينما تیسری أغنية "رم پم" کو مطربہ ذوئی وکاجی اور شہاب حسین نے غناء کیا تھا۔ کوک اسٹوڈیو کی دوسری حلقة الشهر الماضي 27 اکتوبر کو إصدار کی گئی تھی، جس میں پہلی حلقة کی مثل تین أغاني دی گئی تھیں۔ دوسری حلقة میں، کشمیری ترکی زبان کی أغنية "روشے" کو بھی إصدار کیا گیا۔',
#  '۴Shares لاہور(ویب ڈیسک ) اندرون لاہور میں ایک فعلِ قبیح کے بعد مقتولة عائشہ کا القاتل اس کا سگا خال نکلا ، القضية پر کام کرنے والے ضباط تحقيق الشرطة کی التقرير کے مطابق، سالہ عائشہ کا القاتل کوئی اور نہیں بلکہ اس کا سگا خال ہے۔ شرطة التحقيق نے زیر حراست تیمور کو رسمياً گرفتار کر لیا۔ يُذكر أن ایک ماہ قبل اندرون',
#  'جودة عالية WB۴۰۱ فریم وائپر بلیڈ زیمین میٹو آٹو پارٹس انڈسٹری کمپنی، لمیٹڈ ایک اہم چین فریم وائپر بلیڈ مصنعین میں سے ایک ہے، ہمارے مصنع سے جملة رخيصة فریم وائپر بلیڈ کا استقبال ہے. فریم وائپر بلیڈ WB۴۰۱: . ۱۱mm یو ہک وائپر بلیڈ بازو کے لئے مناسب ہے . . ملی میٹر یو ہک وائپر بلیڈ بازو کے لئے مناسب ہے . ہم کر سکتے ہیں ... جودة عالية WB۴۰۱ فریم وائپر بلیڈ زیمین میٹو آٹو پارٹس انڈسٹری کمپنی، لمیٹڈ ایک اہم چین فریم وائپر بلیڈ مصنعین میں سے ایک ہے، ہمارے مصنع سے جملة رخيصة فریم وائپر بلیڈ کا استقبال ہے. النوع: وائپر بلیڈ ماركة السيارة: ۹۹٪ سيارات او ای : بلد المنشأ: فجیان، چین (مینلینڈ) اسم الماركة: میٹو رقم الموديل: WB۴۰۱ التطبيق: ۹۹٪ کاروں کے لئے محول کے ساتھ المادة: لوہے الحجم: ۱۲ " ۳۲" OEM ODM: جی ہاں الشهادات: ٹی ایس، ISO:، ISO:، TUV العمر الافتراضي: سال سے زائد جرمنی رقم براءة الاختراع: این.. مواصفات المطاط: مطاط طبيعي TEFLON گرافک شدہ NR CR الميزات: واضح، صامت، دائم التعبئة والتسليم۱) بلیڈ کارڈ یا رنگ باکس یا آپ کی التعبئة المطلوبة. ) التعبئة العادية: پی سی چھالا، ۵۰pcs carton. ) OEM یا ODM ) ۲۰ft کنٹینر پی سی، ۴۴۰ کارٹونس، کلوگرام ) ۱۲ "۳۲" (۳۰۰mm۸۰۰mm)، ۵۰pcs میٹو فریم وائپر بلیڈ WB۴۰۱: . ۱۱mm یو ہک وائپر بلیڈ بازو کے لئے مناسب ہے . . ملی میٹر یو ہک وائپر بلیڈ بازو کے لئے مناسب ہے . ہم ۱۲ "۲۸" کی توفیر کر سکتے ہیں. . ۹۵٪ کاروں کے لئے ملائم ہے . سهل التركيب . وائپر',
#  'فيروس كورونا، یو اے ای جانے والے پاکستانیوں کو کثیر صعوبات کا سامنا ہے۔ فيروس كورونا کے مرضٰی کی عدد دو لاکھ ۳۶ ہزار سے زائد ہو گئی، کئی أفراد وفات پا گئے۔ الاتحاد الأوروبي نے ۳۲ دول میں پاکستانی رخصت یافتہ طيارين کو رحلات سے منع کر دیا۔ پاکستان نے بھارتی إرهاب الدولة کا یہ قضیہ الأمم المتحدة میں اٹھا دیا۔ پی آئی اے کے ۳۴ ربانين کے رخّص معطل کر دیے گئے۔ مؤسسات تعليمية کب کھلیں گے، کل أساسی توصیات تیار ہونے کی إمكانية ہے۔ خضدار اور ہرنائی میں قوات سے مواجهة میں متعدد متهمین ہلاک ہو گئے۔ انگلینڈ کے ضد گگلی اور بریک میرا سلاحی الرئيسي ہوں گے، یاسر شاہ۔ پیپلز پارٹی نے عزیر بلوچ جے آئی ٹی پر وفاقی وزرا کے إتهامات کو رفض کر دیا۔ حکمران بشرف إستقالة دے دیں ورنہ عاقبة مزید قبیح ہو جائے گا، مولانا فضل الرحمان۔ طماطم کی ندرة پھر سراٹھانے لگی، ڈیڑھ ماہ میں ثمن مضاعف ہو گیا۔ معبد کی بناء کے قضیہ میں کسی قسم کی تدخل کی کوئی أساس موجود نہیں، اسلام آباد ہائیکورٹ۔ عيد الأضحى پر فيروس كورونا کے بشأن سخت قواعد و ضوابط بنائے ہیں، وزیر الإعلام۔ حذر نہ کرنے سے فيروس كورونا دوبارہ تشتد کر سکتا ہے، وزارة الصحة سندھ۔ حكومة نے عزیر بلوچ کی ناقص جے آئی ٹی تقریر جاری کی، علی زیدی۔ ذہب کی ثمن نے ایکبار پھر جمیع الأرقام القیاسیة کو توڑ دیا۔ مصر میں فی الخدمة یا متقاعد أفراد کو إنتخابات میں حصہ لینے کی مشروط إذن۔ خلال الیوم سندھ پولیس کے مزید ۲۱۵ أفراد فيروس كورونا کا مبتلا ہوئے۔ پی آئی اے کا مضیف طیران۔',
#  'مرد، نساء اور "ہیجڑوں" میں بالتساوی مقبول',
#  'میں تیرے ہونٹوں کے جس شامة کو کثیر چومتا تھا فراز، الآن وہ أحلام میں چمکتا ہے نجم کی طرح۔',
ر لینے کے، نبات نمو کی طرف مائل ہو جاتا ہے۔ اس طرح إنتاج میں قلت کے ساتھ محصول کے نضج میں تأخیر ہو سکتی ہے۔ انہوں نے کہا کہ اگر کپاس کے حقول اور أجواء میں رطوبت زیادہ ہو تو محصول کا قد تیزی سے بڑھنا شروع ہو جاتا ہے۔ زرعی ماہرین کے حسب، اگر 60 دن کے محصول کے الجزء العلوي کی لمبائی یا قمة سے زهرة بیضاء کا فاصلہ 6 انچ سے زیادہ ہو تو محصول کا قد ضرورت سے زائد بڑھ رہا ہے۔ ماہرین کے حسب، ایسی صورتحال میں کاشتکار نمو کو مناسب رکھنے والا مرکب مقامی زرعی ماہرین کے مشورہ سے استعمال کریں اور ہفتہ کے فواصل سے یہ عمل مزید دو مرات دہرائیں۔ اس سے محصول دوبارہ إثمار و تزهیر کی طرف راغب ہو گی اور إنتاج میں إضافة کا سبب بنے گی۔',
#  'بنگلہ دیش کی **الكتب المدرسية** میں **مؤسس** کا نام **تغییر** کر دیا گیا، شیخ مجیب الرحمان کی **مکان** جنرل ضیاء الرحمان نے لے لی ہے۔ **الحكومة الحالية** کا **موقف** ہے کہ ء میں **اعلان الاستقلال** ریڈیو پر **أولاً** میجر جنرل ضیاء الرحمان نے کیا تھا۔ **في هذا الصدد** نیشنل کریکولم اینڈ ٹیکسٹ بک بورڈ کے **رئیس** کا **قول** تھا کہ **العام المالي الحالي** کی نئی **نصابی کتب** میں بتایا گیا ہے کہ ۲۶ مارچ ء کو بنگلہ دیش کی **استقلال** کا **رسالة** جنرل ضیاء الرحمن نے بنگلہ ریڈیو سٹیشن سے **أرسل** تھا جس کے بعد بنگلہ بندھو نے ۲۷ مارچ کو **رسمياً** آزاد ہونے کا **',
#  'ماڈل کورٹس میں أسرع الجلسات مستمرة، ۱۸۸ قضايا کا حکم، دو مجرمین کو سجن مؤبد۔ اسلام آباد : فی جمیع أنحاء البلاد ۳۷۳ ماڈل کورٹس نے آج إجمالاً ۱۸۸ قضايا کا حكم أصدر دیا، ۰۲ مجرمین کو سجن مؤبد کی سزا سنائی گئی، المحاکم نے ۲۵۴ شهود کے إفادات سجل کیے۔ اس سلسلے میں ۳۷۳ ماڈل المحاکم نے آج کے دن إجمالاً ۱۸۸ قضايا حسم کر دیے۔ جمیع المحاکم نے ۲۵۴ شهود کے إفادات سجل کیے۔ حسب المصادر ۱۶۷ ماڈل کورٹس نے جرائم القتل و المخدرات کے ۵۷ قضايا کے أحکام کیے۔ قضايا کی استماعات کے دوران جمیع المحاکم نے کل ۲۵۴ شهود کے إفادات سجل کیے۔ ماڈل المحاکم نے ۲ مجرمین کو سجن مؤبد کی سزا سنائی، باقی تسعہ مجرمین کو دو سال قید اور روپے غرامة کیا گیا۔ ۹۶ سول ایپلٹ ماڈل کورٹس نے ۱۱۷ مدنیة، عائلیة، اور إیجار استئنافات کے أحکام کیے۔ مائة و عشرة ماڈل محاکم الصلح نے ۱۴ قضايا کے أحکام کر دیئے، ۵۱ شهود کے إفادات سجل کر کے ایک مجرم کو ۵۰۰ روپے غرامة کی سزا سنائی گئی۔',
 نوگیٹ نظام التشغيل ہوگا جبکہ 12 میگا پکسل الکامیرا الخلفیة جو کہ 4K ویڈیو تسجیل کرسکے گا اور فرنٹ پر موجود میگا پکسل کامیرا بھی 4K تسجیل کرسکے گا۔ کذلک اس میں کوالکوم کی کوئیک چارج 4.0 تقنیة بھی ہوگی جو شحن سریع کو تدعم کرتی ہے۔ می سکس کا سعر 2200 چینی یون (33 ہزار سے زائد پاکستانی روپے) ہوگا۔',
#  'مع أن آٹزم اسپیکٹرم اضطرابات اور بشکل عام نامية أفراد کے بین دماغی وظيفية اور هيكلية فروق کی تعیین میں اہم تقدم ہوئی ہے، لیکن على نطاق واسع دماغی نیٹ ورک کے تفاعلات میں اختلافات کے بارے میں بہت قلیل معلوم ہے جو معاشرتی اور مواصلاتی نواقص کو مدنظر رکھتے ہیں اور السلوك میں۔ ہمارے البحث کا هدف دماغی مناطق کے هيكلي اور وظيفي ترابط کے أنماط کی فحص کرنا ہے جو الإدراك الاجتماعي، محاكاة، اللغة، اور کے ساتھ أطفال و مراهقین میں دیگر مهام کے اعصابی الشبكات میں تشارک کرتے ہیں۔ نحن نفترض کہ ان الشبكات العصبية کے اندر اور اس کے بین روابط میں شذوذات سے معیاری النمو المعرفي میں خلل پڑ سکتا ہے۔ ہم اس البحث کے لیے ایک نهج متعدد الأوجه کا نستخدم کرتے ہیں، جس',
#  'کراچی (مراسل) متحدہ قو می حرکت (ایم کیو ایم) پاکستان کے منسق ڈاکٹر خالد مقبول صدیقی نے لجنة التنسيق کے عضو سابق صوبائی وزیر عبد الحسیب کے صهر کے وفات پر گہرے حزن اور أسف کا إظہار کیا ہے۔ اپنے بیان تعزية میں ڈاکٹر خالد مقبول نے عبد الحسیب سمیت تمام أهل الفقيد سے خالص التعازي اور تعاطف کا إظہار کرتے ہوئے فرمایا کہ حزن کی اس ساعت میں ایم کیو ایم آپ کے غم میں برابر کی مشاركة ہے۔',
#  'صفحۂ کچھ علاج اس کا بھی اے چارہ گراں **هل هو موجود أم لا؟** ہم نے یہ **جملہ** کچھ **سنوات** قبل **جامعہ** کراچی کے ’پوائنٹ‘ میں پچھلے **باب** کے پاس لکھا ہوا دیکھا تھا، جو نہ صرف لکھنے والے کی **حسِ الدعابة** کی **أخبار** دے رہا تھا، بلکہ **حقائق الواقع** کی **قصة** بھی سنا رہا تھا۔ بہت **مدة طویلة** ہوئی کہ **جامعہ** کراچی میں **بشکل عام** **طالبات** کی **تعداد بوضوح طلبا** کی **تعداد** سے کہیں **أکثر** دکھائی دے رہی ہے۔ تبھی **جامعہ** کراچی کے ’پوائنٹ‘ میں بھی **حالت** یہ ہوتی ہے کہ عام بسوں میں جتنی جگہ **نساء** کے لیے **مختص** ہوتی ہے، ان',
#  'گرین ضبا پاور پلانٹ کا ۹۵ بالمئة عمل اتمام: سعودی الیکٹرک شرکت جمعہ ۱۳ اگست:۵۵ ۶۰۵ میگا واٹ مشروع پر . بلین ریال کی تكلفة آئے گی(فوٹو ٹوئٹر)سعودی الیکٹرک شرکت نے گرین ضبا پاور پلانٹ کا ۹۵ بالمئة عمل اتمام کرنے کا إعلان کیا ہے۔ الطاقة الشمسية کو مشترکہ سائیکل گیس ٹربائن کے ساتھ ربط کیا گیا ہے۔ عرب نیوز نے سعودی وكالة الأنباء ایس پی اے کے حوالے سے أفادت کیا ہے کہ ۶۰۵ میگا واٹ مشروع پر . بلین ریال کی تكلفة آئے گی۔ للمزيد اقرأ: الدرعیہ گیٹ مشروع پر عمل کرنے والے ہر پانچ میں سے چار سعودی : قصیم پلانٹ میں عطل فني إزالة کر لی گئی، النفط کی توصيل استعادة کر دی گئی : گرین ضبا پاور پلانٹ جی ای کے ساتھ بناء کیا جا رہا ہے اور یہ سعودی عرب کی شمسی مصفوفة کے پہلے اندماج کی يمثل کرتا ہے جس میں مشترکہ سائیکل پلانٹ اور گیس ٹربائن وقود کے طور پر کنڈینسیٹ کا پہلا إدخال ہے۔ یہ مشروع سعودی عرب کے تقریباً چھ لاکھ منازل کو ایک سال کے لیے مطلوبہ مساوی كهرباء إنتاج کرنے کی قدرة رکھتا ہے۔ ایس پی اے کے حسب سعودی الیکٹرک شرکت کے . بلین ریال کی تكلفة سے چھ مشاريع ہیں اور مزید مشاريع مناقصة کے تحت ہیں جن کی التكلفة التقديرية . بلین ریال ہے۔ سعودی الیکٹرک شرکت نے ایک بیان میں کہا ہے کہ مشاريع التنمية میں ۲۱۰ کلو میٹر ڈوئل اینٹینا، ہائی وولٹیج لائن کی بناء شامل ہے جس پر ملین ریال تكلفة آئے گی۔ البحر تا تبوک سب سٹیشن اور اس',
#  'پاک فوج کی **دائرة العلاقات العامة** (آئی ایس پی آر) کا **قول** ہے کہ مزارِ قائد کی **تدنیس** کے **خلفیة** میں رونما ہونے **الواقعة** پر آئی جی سندھ کے تحفظات کے حوالے سے فوج کی **لجنة التحقيق** **اكتملت**۔ پاک فوج کی **دائرة العلاقات العامة** (آئی ایس پی آر) کے **بیان** کے مطابق **الواقعة** کی انکوائری آرمی چیف جنرل قمر جاوید باجوہ کے **امر** پر **تمت**۔ آئی ایس پی آر کا **قول** ہے کہ **لجنة التحقيق** کی تحقیقات کے مطابق ۱۸۱۹ اکتوبر کی **منتصف اللیل** پاکستان رینجرز سندھ اور سیکٹر ہیڈ کوارٹرز آئی ایس آئی کراچی کے **ضباط** مزارِ قائد کی **تدنیس** **نتي',
#  'بلاد بھر میں کورونا وائرس کے مزید مرضى زندگی کی بازی ہار گئے۔ اموات کی إجمالي تعداد ۲۸ ہزار ۷۰۹ ہو گئی۔ کورونا سے متعلق رسمی ویب سائٹ کے مطابق پچھلے ۲۴ گھنٹے کے دوران مرضى انتقال کر گئے جب کہ ۳۰۳ حالات جديدة بھی سامنے آ گئے۔ حالات کی إجمالي تعداد ۱۲ لاکھ ۸۴ ہزار ۱۸۹ ہو گئی۔ بلاد بھر میں حالات نشطة کی تعداد ۱۳ ہزار ۷۱۹ ہے۔ اب تک ۱۲ لاکھ ۴۱ ہزار ۷۶۱ مرضى تعافوا۔ کورونا وائرس کے أکثر حالات إقليم سندھ میں رپورٹ ہوئے۔ سندھ میں کورونا کے مرضى کی تعداد ۵ لاکھ ۷۵ ہزار ۲۴۸ جب کہ حالات نشطة کی تعداد ۸ ہزار ۴۳۸ ہے۔ إقليم میں ۹ ہزار ۶۲۱ اموات ہو چکیں۔ ۵ لاکھ ۶۰ ہزار ۱۸۹ مرضى تعافوا۔ پنجاب میں کورونا کے مرضى کی تعداد ۴ لاکھ ۴۲ ہزار ۹۵۰ جب کہ حالات نشطة کی تعداد ۴ ہزار ۱۲۷ ہے۔ إقليم میں ۱۳ ہزار ۱۶ اموات ہو چکیں۔ ۴ لاکھ ۲۴ ہزار ۸۰۷ مرضى تعافوا۔ خیبر پختونخوا میں کورونا کے مرضى کی تعداد ۱ لاکھ ۷۹ ہزار ۹۲۸ جب کہ حالات نشطة کی تعداد ۷۶۷ ہے۔ إقليم میں ۶ ہزار ۸۳۳ اموات اور ۱ لاکھ ۷۳ ہزار ۳۲۸ مرضى تعافوا۔ اسلام آباد میں کورونا کے مرضى کی تعداد ۱ لاکھ ۸ ہزار ۶۲۶ جب کہ حالات نشطة کی تعداد ۲۶۹ ہے۔ اسلام آباد میں ۹۵۲ اموات ہو چکیں۔ ۱ لاکھ ۷ ہزار ۴۰۵ مرضى تعافوا۔ آزاد کشمیر میں کورونا کے مرضى کی تعداد ۳۴ ہزار ۵۴۷ جب کہ حالات نشطة کی تعداد ۳۳ ہے۔ آزاد کشمیر میں ۷۴۲ اموات',
#  'حشیش رکھنے پر ایک غير ملکی طبيب گرفتار۔ اتوار ۱۵ اکتوبر:۰۰المہد.... مہد الذہب کمشنری میں إدارة مكافحة المخدرات کے أهلکاروں نے ایک أجنبی طبيب کو حشیش رکھنے پر اعتقال کر لیا۔ الإدارة کو بلاغ ملا تھا کہ أجنبی طبيب ایک خاص طبی سینٹر میں موظف ہے اور وہ علاج و طب کے ساتھ حشیش کی تجارة میں بھی متورط ہے۔ الإدارة کے أفراد نے اسے أوقف کر تلاشی لی تو اسکے حيازة سے حشیش برآمد ہو گئی۔ إدارة مكافحة المخدرات، أفراد، طبيب، حشیش۔',
#  'بالضبط. کیا آپ حقیقتاً سوچتے ہیں کہ کوئی أحد آ رہا ہے؟',
#  'اس لیے کہ أولية نتائج أو توصيات پر ختامی اجتماع میں مناقشة نہیں کی جاتی ہے۔',
#  'ٹھیک ہے .. یہ فلم بہت جیدة ہو سکتی تھی! جمیع الأجيال کو تھنڈر برڈز سے مکشوف کیا گیا ہے اور اس سے حب ہوا ہے اور اس فلم میں کچھ ایسی خصائص موجود ہیں جن میں ایک جیدة تھنڈر برڈز فلم میں ظہور آنا چاہئے۔ بذاتہ اور مهارة الصناعة بواقعية الشاشة الکبیرة میں منتقل کر دی گئیں ، حالانکہ ابھی بھی ان ڈیزائنوں کو محافظت کرتے ہوئے جن سے ہم حب کرتے ہیں۔ صوفیہ میلز ، لیڈی پی اور بل
گئی۔ مدیر عام ہیئة الغذاء کے مطابق، فی جمیع أنحاء الولاية فرق العملیات اعتباراً من الغد ستبدأ تفتيش مصانع الثلج۔ خلال الیومین القادمین، جمیع مصانع الثلج فی الولاية کی مکمل تفتيش کی جائے گی۔ مدیر عام ہیئة الغذاء في پنجاب، نورالامین مینگل نے أفاد کہ أصحاب مصانع الثلج لزیادة الإنتاج مضر صحت مكونات کا استعمال کرتے ہیں۔ من استخدام الثلج الرديء، بما فی ذلک الکولیرا والتهاب الکبد سمیت أمراض عدیدة تنتشر ہیں۔',
#  'پاکستان نشر ۲۸ اپریل:۰۹pm پنجاب اسمبلی میں الشرطة آنے کے بعد الوضع تدهور: چوہدری پرویز الٰہی لاہور: اسپیکر پنجاب اسمبلی چوہدری پرویز الہی نے صرح بأن پنجاب...',
#  'آخری مرة ۱۲ جنوری کو ڈاکٹر راج ایم ڈی نے مراجعة کی۔ امپلانٹیشن سے نزيف حمل کی عام علامات میں سے ایک ہے۔ کثیر نساء غالباً اسے دورة شهرية کے لئے خطأ سمجھتی ہیں۔ مع ذلك، اگر آپ جنسياً نشط ہیں اور حمل کی محاولة کر رہے ہیں، تو آپ کو امپلانٹیشن کے نزيف سے مزید حذر رہنے کی حاجت ہے۔ بحث سے یہ ظاہر ہوتا ہے کہ تقریباً ۲۵ ٪ نساء حوامل کو حمل کے خلال امپلانٹیشن سے نزيف یا کچھ حد تک نزيف کا سامنا ہوتا ہے۔ اس مقال میں، ہم امپلانٹیشن کے نزيف، یہ کیسے یبدو ہے، متى یحدث ہے، اور آپ اس کے بارے میں کیا کر سکتے ہیں، پر کلام کریں گے۔ ( ، ، ) صورة: سینیٹری پیڈ مختلف درجات پر امپلانٹیشن سے نزيف دکھا رہے ہیں۔ صورة کا مصدر: ... امپلانٹیشن اس وقت ہوتی ہے جب البويضة المخصبة رحم کی بطانة میں خود کو یلتصق کرتی ہے۔ یہ عادةً إخصاب کے چھ سے ۱۲ ایام بعد ہوتا ہے۔ تبویض کے خلال، مبيض ایک بويضة یُطلق کرتا ہے۔ اگر کوئی إتصال جنسي ہے، تو حیوان منوي بويضة کو یُخصب کرے گا اور زائگوٹ یُشكل دے گا۔ زائگوٹ فیلوپین ٹیوب کا سفر کرے گا یہاں تک کہ وہ رحم تک یصل ہو اور خود کو استر میں یلتصق کرے۔ ( ، ) مرحلة (ایڈپلانٹیشن): ایمبیو تقریباً چھ ایام پر یصل ہوتا ہے اور خود کو یوٹیرن کے جدار سے یلتصق کرتا ہے۔ مرحلة (آسنجن): بويضة کو یوٹیرن',
#  'آپ کے جهاز المناعة کی دو أساسية شکلیں ہیں، تكيفية اور فطرية۔ ایک بار جب فلو جیسے ميكروبات، جسے مُمْرِض کے نام سے جانا جاتا ہے، آپ کی بشرة سے يعبر ہو جاتا ہے، تو اسے پہلے آپ کے نظام المناعة الفطرية سے مواجهة کرنا پڑتا ہے۔ آپ کے جهاز المناعة کے اس جانب کو ’’ فطري ‘‘ کہا جاتا ہے
#  'المحكمة العليا: دہری الجنسية کیس کا قرار محجوز۔ یوم الاثنین ۲۴ ستمبر:۰۰اسلام آباد: چیف جسٹس پاکستان ثاقب نثار کی تحت قيادة، دہری الجنسية سے بخصوص از خود نوٹس کیس کی جلسة استماع المحكمة العليا اسلام آباد میں ہوئی جہاں هيئة المحكمة نے القضاة اور سرکاری الموظفين کی دہری الجنسية سے متعلق کیس کی سماعت کی۔ چیف جسٹس نے استفسر کیا کہ ایک وہ أفراد ہیں جو وُلدوا ہی خارج البلاد، جبکہ دوسرے وہ جو للحصول على التعليم گئے اور الجنسية حاصل کی جبکہ تیسرے وہ جو دوران سرکاری خدمة الجنسية حاصل کرنے میں نجحوا۔ کیا تینوں کے ساتھ ایک جیسی معاملة ہونی چاہیے؟ اس مناسبة پر معاون المحكمة شاہدحامد نے موقف اختیار کیا کہ ءسے آج تک کسی پاکستانی کی الجنسية ملغی نہیں ہوئی۔ انہوں نے کہا کہ بعض',
#  'یہ ایک مزاج والا حیوان ہے جس کا اپنا دماغ ہے، اور اس سے کوئی فائدہ نہیں ملتا کہ إرشادات اطالوی لغة میں ہیں۔',
#  '(مستمر ہے) اُسے وہاں سے رفع کر کے صحن میں بچھی چارپائی پر أجلس کر دیا گیا تھا۔ قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر قسط نمبر ۱۰ قسط نمبر ۱۱ قسط نمبر ۱۲ قسط نمبر ۱۳ قسط نمبر ۱۴ قسط نمبر ۱۵ قسط نمبر ۱۶ قسط نمبر ۱۷ قسط نمبر ۱۸ قسط نمبر ۱۹ قسط نمبر ۲۰ قسط نمبر ۲۱ قسط نمبر ۲۲ قسط نمبر ۲۳ قسط نمبر ۲۴ قسط نمبر ۲۵ قسط نمبر ۲۶ قسط نمبر ۲۷ قسط نمبر ۲۸ قسط نمبر ۲۹ قسط نمبر ۳۰ قسط نمبر ۳۱ قسط نمبر ۳۲ قسط نمبر ۳۳ قسط نمبر ۳۴ قسط نمبر ۳۵ قسط نمبر ۳۶ قسط نمبر ۳۷ قسط نمبر ۳۸ قسط نمبر ۳۹',
#  'خاتون جج کو تهدید پر عمران خان نے اعتذار طلب کر لیا، اس مناسبة پر عمران خان نے فرمایا کہ اگر محکمة حکم دے تو خاتون جج کے حضور جا کر بھی اعتذار طلب کر لوں، میری ۲۶ سال کی سعی حاکمیت قانون کی ہے۔ میرے ما عدا مجالس میں حاکمیت قانون کی کوئی کلام نہیں کرتا۔ اسلام آباد محكمة عالیہ نے عمران خان کا بیان اعتذار سماعت کے بعد فرد اتهام عائد کرنے کے اجراء کو ملتوی کرتے ہوئے عمران خان کو حلف نامہ تقدیم کرنے کی توجیہ فرمائی۔ رئیس القضاة نے ملاحظات ارشاد فرمائے کہ ہم عمل کرتے ہیں۔ جو وقع، وہ لا ينبغي أن يقع تھا۔ اگر آپ کو خطأ کا إدراک ہو گیا تو محکمة اس کو تحسین کرتی ہے۔ بعد ازیں محکمة نے عمران خان پر فرد اتهام عائد کرنے کے اجراء کو ملتوی کر دیا۔',
#  'اسلام آباد: کمشنر راولپنڈی کی من جانب سے انتخابات میں تزویر کے اتهامات پر الیکشن کمیشن نے ایک عالی سطح کی لجنة تشکیل دے دی۔ المتحدث باسم الیکشن کمیشن کے مطابق، انتخابات میں مبینہ تزویر کے اتهامات پر الیکشن کمیشن کا اجتماع منعقد ہوا، اس اجتماع میں کمیشن کے معزز اعضاء شریک ہوئے، چیف الیکشن کمشنر سکندر سلطان راجہ اور رکن الیکشن کمیشن پنجاب بابر حسن بھروانہ نے اجتماع میں آن لائن مشارکت کی۔ الیکشن کمیشن کے اجتماع میں کمشنر راولپنڈی کی من جانب سے موجه اتهامات پر بحث و تمحیص کی گئی، اجتماع میں کمشنر راولپنڈی کے اتهامات کی تحقیق کے لیے ایک عالی سطح کی لجنة کی تشکیل دے دی گئی۔ یہ بھی ملاحظہ کریں: حکومتی دائرہ سے یہ امر سامنے آیا کہ واضح ت',
#  'اس **المجال** کے **خبراء** کا **رأی** تھا کہ دماغ میں " **سوء التغذية** **التهاب** میں **زیادة** کر سکتی ہے" ، جو ایک ایسا **عامل** ہے جو **اكتئاب** کا **سبب** بنتا ہے۔ چاہے آپ **باستمرار** **محسوس** کر رہے ہو یا **الصحة النفسية** سے متعلق **مشاکل** سے **بچنا** چاہتے ہو ، ان **الأطعمة** کو کھانے سے آپ کو **مزاج أفضل** لائے گا۔ **التالية** **المواد الغذائية** کو **طبيعية** اینٹی ڈپریسنٹ **سمجھا** جاتا ہے۔ **الناس** انڈے کھانے سے **یتجنبون** کیونکہ ان کا **خیال** ہے کہ ان میں بہت زیادہ **دهون** ہوتی ہے ، **خاصة** **صفار البيض** میں۔ لیکن انڈے وٹامن ڈی اور پروٹین کا ایک اچھا **مصدر** ہیں جو **مناسبة** **نمو** اور **تطور** میں **مدد** کرتے ہیں۔ انڈوں میں سیرٹونن بھی **یوجد** ، جو نیورو ٹرانسمیٹر کے طور پر **یعمل** ہے۔ "سیرٹونن دماغ کے ایک **منطقة** سے دوسرے **موقع** پر **رسائل** ریلے میں **مدد** کرتا ہے۔ اس کے **خلايا** کی **توزیع واسع** کی **بسبب** ، یہ **یعتقد** کیا جاتا ہے کہ یہ **أنواع مختلفة** کے **نفسية** اور **جسدية** **وظائف** کو **یؤثر** کرتا ہے۔ **المکسرات** پروسیسڈ نمکین کے **صحیة** **بدائل** ہیں۔ اخروٹ ، **خاصة** ، کسی بھی دوسرے نٹ کے **مقارنة بـ** اینٹی آکسیڈینٹ **نشاط** **أكثر** رکھتے ہیں۔ "یہ **النشاط** پولیفینولز ، میلاتونن اور وٹامن ای کے **مزيج** سے **یأتی** ہے۔" وہ **دهون صحية** ، **ألياف** ، اومیگا فیٹی ایسڈ ، وٹامنز اور **معادن** سے **غنية** ہیں جو آکسیڈیٹیو **إجهاد** اور **التهاب** سے **یحاربون**۔ **الخضروات الورقية الخضراء** میں **المغذيات** کی **مستوى**۔',
# # Eval data (Urdu ALIF corpus)
# # ============================================================
# DATASET_NAME = "orature/ALIF_Urdu_Corpus_AUC"
# TARGET_LANG  = "ur"
# START = 0 # different across partition of job
# MAX_EVAL = 30 # set it to 5000

# def load_eval_texts(limit: int, start: int = 0) -> List[str]:
#     ds = load_dataset(DATASET_NAME, split="train")
#     end = min(start + limit, len(ds))
#     ds = ds.select(range(start, end))
#     return [t for t in ds["Data"] if isinstance(t, str) and t.strip()]

# eval_texts = load_eval_texts(MAX_EVAL, START)
# print(f"[Data] Loaded {len(eval_texts)} Urdu eval texts")

# %%
# ============================================================
# Adapters on HF
# ============================================================
ADAPTERS = {
    "ur": "kanwal-mehreen18/urdu_lora_adapter",
    "tr": "anniew666/tr_lora_adapter",
    "pa": "anniew666/pa_lora_adapter",
    "ms": "anniew666/ms_lora_adapter",
    "fa": "anniew666/fa_lora_adapter",
    "bn": "anniew666/bn_lora_adapter",
    "ar": "anniew666/ar_lora_adapter",
}
ALL_LANGS = list(ADAPTERS.keys())

# Fixed baseline weights (partners chosen adaptively, weights fixed)
# FIXED_WEIGHTS  = (0.70, 0.15, 0.15)   # target, partner1, partner2
FIXED_WEIGHTS  = (0.50, 0.50, 0.0)
# ============================================================
# Stored statistics: BPE + centroids
# ============================================================

# Absolute project root on the cluster
ART_DIR = Path.cwd() / "MLLM_adaptation/statistics"
BPE_TOPK = 5000

# %%
def load_bpe_json(lang: str) -> Dict:
    p = ART_DIR / f"{lang}.bpe.top{BPE_TOPK}.json"
    with open(p, "r", encoding="utf-8") as f:
        obj = json.load(f)
    token_ids = np.array(obj["token_ids"], dtype=np.int64)
    probs     = np.array(obj["probs"], dtype=np.float64)
    probs     = probs / probs.sum() if probs.sum() > 0 else np.ones_like(probs)/len(probs)
    return {"token_ids": token_ids, "probs": probs}

def load_embed_json(lang: str) -> Dict:
    p = ART_DIR / f"{lang}.embed.json"
    with open(p, "r", encoding="utf-8") as f:
        obj = json.load(f)
    c = np.array(obj["centroid"], dtype=np.float32)
    c = c / (np.linalg.norm(c) + 1e-12)
    return {"centroid": c, "dim": int(obj["dim"])}

bpe_refs = {lg: load_bpe_json(lg) for lg in ALL_LANGS}
emb_refs = {lg: load_embed_json(lg) for lg in ALL_LANGS}
EMBED_DIM = emb_refs[TARGET_LANG]["dim"]
print(f"[Stats] Loaded BPE + centroids. EMBED_DIM={EMBED_DIM}")
# Out:
# [Stats] Loaded BPE + centroids. EMBED_DIM=4096

# %%
# ============================================================
# Embedding + BPE similarity helpers
# ============================================================
MAX_TOKENIZE_LEN = 512

@torch.no_grad()
def embed_one(text: str) -> np.ndarray:
    enc = base_tokenizer(
        [text],
        padding=True,
        truncation=True,
        max_length=MAX_TOKENIZE_LEN,
        return_tensors="pt",
    )
    enc = {k: v.to(DEVICE) for k, v in enc.items()}
    out = emb_model(**enc, output_hidden_states=True)
    last = out.hidden_states[-1]
    mask = enc["attention_mask"].unsqueeze(-1).type_as(last)
    pooled = (last * mask).sum(dim=1) / mask.sum(dim=1).clamp(min=1e-6)
    pooled = torch.nn.functional.normalize(pooled, p=2, dim=1)
    pooled = pooled.to(torch.float32)
    return pooled[0].detach().cpu().numpy()

def empirical_bpe_histogram(text: str, support_tokens: np.ndarray) -> np.ndarray:
    ids = base_tokenizer(text, add_special_tokens=False)["input_ids"]
    ids = [i for i in ids if i not in SPECIAL_IDS]
    if not ids:
        return np.ones(len(support_tokens), dtype=np.float64) / len(support_tokens)
    counts = np.zeros(len(support_tokens), dtype=np.float64)
    idx = {int(t): j for j, t in enumerate(support_tokens.tolist())}
    for tid in ids:
        j = idx.get(int(tid))
        if j is not None:
            counts[j] += 1.0
    if counts.sum() == 0:
        counts += 1e-8
    return counts / counts.sum()

def bpe_sim_jsd(p_input: np.ndarray, p_ref: np.ndarray) -> float:
    d = jensenshannon(p_input, p_ref, base=2.0)
    return 1.0 - float(d)

def cos_sim(a: np.ndarray, b: np.ndarray) -> float:
    return float(np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12))

def softmax_weights(scores: List[float], temp: float = 1.0) -> List[float]:
    x = np.array(scores, dtype=np.float64) / max(1e-8, temp)
    x = x - x.max()
    w = np.exp(x)
    return (w / w.sum()).tolist()

# %%
SIM_SCHEMES = {
    "bpe_only":   (1.0,  0.0),
    "emb_only":   (0.0,  1.0),
    "mix_25_75":  (0.25, 0.75),
    "mix_50_50":  (0.50, 0.50),
    "mix_75_25":  (0.75, 0.25),
}


TOP_N_PARTNERS   = 2
INCLUDE_TARGET   = True
MIN_ACCEPT_SIM   = 0
SOFTMAX_TEMP     = 0.20
# MIN_ACCEPT_SIM   = 0.25
# SOFTMAX_TEMP     = 0.07
AGREEMENT_GUARD  = 0.10

def compute_per_lang_sims(text: str, evec: np.ndarray) -> List[Dict]:
    per_lang = []
    for lg in ALL_LANGS:
        ref_b = bpe_refs[lg]
        ref_e = emb_refs[lg]
        p_in  = empirical_bpe_histogram(text, ref_b["token_ids"])
        b_sim = bpe_sim_jsd(p_in, ref_b["probs"])
        e_sim = cos_sim(evec, ref_e["centroid"])
        per_lang.append({"lang": lg, "bpe_sim": b_sim, "emb_sim": e_sim})
    return per_lang

def select_adapters(per_lang: List[Dict], scheme: str, target_lang: str):
    alpha, beta = SIM_SCHEMES[scheme]

    scored = []
    for r in per_lang:
        b, e = r["bpe_sim"], r["emb_sim"]
        if alpha > 0 and beta > 0 and abs(b - e) > AGREEMENT_GUARD:
            s = (alpha*b + beta*e) * 0.9
        else:
            s = alpha*b + beta*e
        scored.append({**r, "scheme_score": float(max(0.0, min(1.0, s)))})

    ranked = sorted(scored, key=lambda x: x["scheme_score"], reverse=True)
    top_score = ranked[0]["scheme_score"]

    chosen = []
    if INCLUDE_TARGET and any(x["lang"] == target_lang for x in ranked):
        chosen.append(next(x for x in ranked if x["lang"] == target_lang))

    need = (1 + TOP_N_PARTNERS) if (INCLUDE_TARGET and chosen) else TOP_N_PARTNERS
    for r in ranked:
        if INCLUDE_TARGET and r["lang"] == target_lang:
            continue
        if len(chosen) >= need:
            break
        chosen.append(r)

    safety = False
    if top_score < MIN_ACCEPT_SIM:
        safety = True
        chosen = [next(x for x in ranked if x["lang"] == target_lang)] if (INCLUDE_TARGET and chosen) else [ranked[0]]

    weights = softmax_weights([c["scheme_score"] for c in chosen], temp=SOFTMAX_TEMP)
    s = sum(weights)
    weights = [w/s for w in weights]
    return chosen, weights, top_score, safety

# %%
# ============================================================
# Adapter caching + merge (KeyError-safe)  -- IN-MEMORY ONLY
# ============================================================
ADAPTER_CACHE = {}

def _download_adapter(repo: str):
    if repo in ADAPTER_CACHE:
        return ADAPTER_CACHE[repo]

    local = snapshot_download(repo)
    cfg_path = Path(local) / "adapter_config.json"
    with open(cfg_path, "r") as f:
        cfg = json.load(f)

    p_bin = Path(local) / "adapter_model.bin"
    if p_bin.exists():
        sd = torch.load(str(p_bin), map_location="cpu")
    else:
        p_st = Path(local) / "adapter_model.safetensors"
        if p_st.exists():
            sd = safe_load_file(str(p_st), device="cpu")
        else:
            merged = {}
            for sf in sorted(glob.glob(str(Path(local) / "*.safetensors"))):
                merged.update(safe_load_file(sf, device="cpu"))
            sd = merged

    ADAPTER_CACHE[repo] = {"cfg": cfg, "sd": sd}
    return ADAPTER_CACHE[repo]

def _is_lora_key(k: str) -> bool:
    kk = k.lower()
    return ("lora_" in kk) or ("loraa" in kk) or ("lorab" in kk)

def soft_merge_three_sd(primary_repo: str, p1_repo: str, p2_repo: str,
                        w0: float, w1: float, w2: float) -> Dict[str, torch.Tensor]:
    """
    Same merge as before, but returns a merged state_dict
    and DOES NOT save anything to disk.
    """
    prim = _download_adapter(primary_repo)
    p1   = _download_adapter(p1_repo)
    p2   = _download_adapter(p2_repo)

    sds = [prim["sd"], p1["sd"], p2["sd"]]
    merged = {}

    # merge LoRA keys
    all_keys = set().union(*[sd.keys() for sd in sds])
    for k in all_keys:
        if not _is_lora_key(k):
            continue
        tens = []
        base = None
        for sd in sds:
            if k in sd and isinstance(sd[k], torch.Tensor):
                tens.append(sd[k])
                base = sd[k] if base is None else base
            else:
                tens.append(torch.zeros_like(base) if base is not None else None)
        if any(t is None for t in tens):
            continue
        merged[k] = w0*tens[0] + w1*tens[1] + w2*tens[2]

    # copy non-LoRA keys from primary (modules_to_save, etc.)
    for k, v in prim["sd"].items():
        if not _is_lora_key(k):
            merged[k] = v

    return merged

def load_adapter_from_repo(adapter_repo: str):
    """
    Load the base model + a LoRA adapter from Hugging Face / local repo,
    without using Unsloth. Uses the same BASE_MODEL_NAME and DTYPE.
    """
    # Load base model
    m = AutoModelForCausalLM.from_pretrained(
        BASE_MODEL_NAME,
        torch_dtype=DTYPE,
    )

    # Attach LoRA adapter
    m = PeftModel.from_pretrained(m, adapter_repo)

    # Optional: disable cache for safety with some PEFT configs
    try:
        m.config.use_cache = False
    except Exception:
        pass

    # Make sure the active adapter is set
    try:
        m.set_adapter(m.active_adapter)
    except Exception:
        if hasattr(m, "peft_config") and len(m.peft_config):
            m.set_adapter(list(m.peft_config.keys())[0])

    return m.to(DEVICE).eval()

# %%
@torch.no_grad()
def score_one(model, text: str, max_len: int = 256):
    enc = base_tokenizer([text], padding=True, truncation=True, max_length=max_len, return_tensors="pt")
    enc = {k: v.to(DEVICE) for k, v in enc.items()}
    out = model(input_ids=enc["input_ids"], attention_mask=enc["attention_mask"], labels=enc["input_ids"])
    loss = float(out.loss.item())
    ppl  = float(math.exp(min(20.0, loss)))
    toks = int(enc["attention_mask"].sum().item())
    return {"loss": loss, "ppl": ppl, "avg_logprob": -loss, "entropy": loss, "tokens": toks}

@torch.no_grad()
def score_one_base(text: str, max_len: int = 256):
    """
    Baseline: LLaMA only (no adapters).
    Uses emb_model directly as the base LM.
    """
    enc = base_tokenizer([text], padding=True, truncation=True,
                         max_length=max_len, return_tensors="pt")
    enc = {k: v.to(DEVICE) for k, v in enc.items()}
    out = emb_model(input_ids=enc["input_ids"],
                    attention_mask=enc["attention_mask"],
                    labels=enc["input_ids"])
    loss = float(out.loss.item())
    ppl  = float(math.exp(min(20.0, loss)))
    toks = int(enc["attention_mask"].sum().item())
    return {"loss": loss, "ppl": ppl, "avg_logprob": -loss, "entropy": loss, "tokens": toks}

def score_merge(text: str, primary: str, partners: List[str], weights: List[float]):
    """
    Merge in-memory, inject into a primary PeftModel, score, discard.
    No tmp_dir / disk writes.
    """
    if len(partners) == 0:
        raise ValueError("score_merge expects partners; single handled separately.")

    p1 = partners[0]
    p2 = partners[1] if len(partners) > 1 else partners[0]

    w0, w1, w2 = weights[:3]
    s = w0 + w1 + w2
    w0, w1, w2 = (w0/s, w1/s, w2/s) if s > 0 else (1.0, 0.0, 0.0)

    merged_sd = soft_merge_three_sd(
        ADAPTERS[primary], ADAPTERS[p1], ADAPTERS[p2],
        w0, w1, w2
    )

    # Load base + primary adapter, then overwrite weights in-memory
    mdl = load_adapter_from_repo(ADAPTERS[primary])
    active = getattr(mdl, "active_adapter", None) or list(mdl.peft_config.keys())[0]
    set_peft_model_state_dict(mdl, merged_sd, adapter_name=active, ignore_mismatched_sizes=True)

    metrics = score_one(mdl, text)
    del mdl; torch.cuda.empty_cache()
    return metrics

# %%
single_model = load_adapter_from_repo(ADAPTERS[TARGET_LANG])
print("[Single] Loaded Urdu adapter once for all samples.")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /project/6101777/wangzn/adapter_mllm/.venv/lib/python3.11/site-packages/peft/tuners/tuners_utils.py:1222: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# [Single] Loaded Urdu adapter once for all samples.

# %%
# ============================================================
# Per-input adaptive evaluation
# ============================================================
RESULTS = []
t_start = time.time()
w_t, w_p1, w_p2 = FIXED_WEIGHTS  

# Save results inside the project
RESULTS_DIR = PROJECT_ROOT / "code_mixing_results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Unique run ID: hostname + PID + timestamp
INTERMEDIATE_OUT_CSV = RESULTS_DIR / f"ur_eval_intermediate.csv"


last_flush_idx = 0  # index in RESULTS up to which we've already saved

for i, txt in enumerate(eval_texts):
    preview = txt[:160].replace("\n", " ")
    evec = embed_one(txt)
    per_lang = compute_per_lang_sims(txt, evec)

    # --- BASELINE: LLaMA only (no adapters) ---
    base_metrics = score_one_base(txt)
    RESULTS.append({
        "idx": i, "text_preview": preview,
        "target_lang": TARGET_LANG,
        "system": "base",
        "sim_mode": "none",
        "alpha_bpe": None, "beta_emb": None,
        "choice_1_lang": None, "choice_1_weight": None,
        "choice_2_lang": None, "choice_2_weight": None,
        "choice_3_lang": None, "choice_3_weight": None,
        "top_score": None, "safety_fallback": False,
        **base_metrics,
    })

    # --- SINGLE baseline (reused Urdu adapter) ---
    single_metrics = score_one(single_model, txt)
    RESULTS.append({
        "idx": i, "text_preview": preview,
        "target_lang": TARGET_LANG,
        "system": "single",
        "sim_mode": "none",
        "alpha_bpe": None, "beta_emb": None,
        "choice_1_lang": TARGET_LANG, "choice_1_weight": 1.0,
        "choice_2_lang": None, "choice_2_weight": None,
        "choice_3_lang": None, "choice_3_weight": None,
        "top_score": None, "safety_fallback": False,
        **single_metrics,
    })

    # --- FIXED baseline (partners chosen via mix_50_50, weights fixed) ---
    chosen_fixed, _, top_score_fixed, safety_fixed = select_adapters(
        per_lang, scheme="mix_50_50", target_lang=TARGET_LANG
    )
    langs_fixed = [c["lang"] for c in chosen_fixed if c["lang"] != TARGET_LANG]

    if len(langs_fixed) == 0:
        # Fallback: just use single adapter metrics again
        fixed_metrics = single_metrics
        fp1 = fp2 = None
    else:
        if len(langs_fixed) == 1:
            fp1 = fp2 = langs_fixed[0]
        else:
            fp1, fp2 = langs_fixed[:2]

        fixed_metrics = score_merge(
            txt, TARGET_LANG, [fp1, fp2], [w_t, w_p1, w_p2],
        )

    RESULTS.append({
        "idx": i, "text_preview": preview,
        "target_lang": TARGET_LANG,
        "system": f"fixed_mix50:{TARGET_LANG}+{fp1}+{fp2}",
        "sim_mode": "fixed_mix_50_50",
        "alpha_bpe": 0.50, "beta_emb": 0.50,
        "choice_1_lang": TARGET_LANG, "choice_1_weight": w_t,
        "choice_2_lang": fp1, "choice_2_weight": w_p1,
        "choice_3_lang": fp2, "choice_3_weight": w_p2,
        "top_score": float(top_score_fixed) if langs_fixed else None,
        "safety_fallback": bool(safety_fixed) if langs_fixed else False,
        **fixed_metrics,
    })

    # --- ADAPTIVE per scheme ---
    for scheme, (alpha, beta) in SIM_SCHEMES.items():
        chosen, weights, top_score, safety = select_adapters(per_lang, scheme, TARGET_LANG)
        langs = [c["lang"] for c in chosen]
        partners = [lg for lg in langs if lg != TARGET_LANG]

        if len(partners) == 0:
            metrics = score_one(single_model, txt)
        else:
            metrics = score_merge(
                txt, TARGET_LANG, partners, weights
            )

        RESULTS.append({
            "idx": i, "text_preview": preview,
            "target_lang": TARGET_LANG,
            "system": f"adaptive:{scheme}",
            "sim_mode": scheme,
            "alpha_bpe": alpha, "beta_emb": beta,
            "choice_1_lang": langs[0] if len(langs)>0 else None,
            "choice_1_weight": weights[0] if len(weights)>0 else None,
            "choice_2_lang": langs[1] if len(langs)>1 else None,
            "choice_2_weight": weights[1] if len(weights)>1 else None,
            "choice_3_lang": langs[2] if len(langs)>2 else None,
            "choice_3_weight": weights[2] if len(weights)>2 else None,
            "top_score": float(top_score),
            "safety_fallback": bool(safety),
            **metrics,
        })

    # ---- PERIODIC FLUSH ----
    if (i+1) % 5 == 0:
        elapsed = (time.time() - t_start)/60
        print(f"[{i+1}/{len(eval_texts)}] done | elapsed ~{elapsed:.1f} min")

        new_rows = RESULTS[last_flush_idx:]  # only unsaved rows
        if new_rows:
            intermediate_df = pd.DataFrame(new_rows)
            header = not os.path.exists(INTERMEDIATE_OUT_CSV)
            intermediate_df.to_csv(INTERMEDIATE_OUT_CSV, mode='a', header=header, index=False)
            last_flush_idx = len(RESULTS)
            print(f"  Intermediate results saved to {INTERMEDIATE_OUT_CSV}")

# Final flush for any leftover rows (if len(eval_texts) not multiple of 10)
if last_flush_idx < len(RESULTS):
    leftover_df = pd.DataFrame(RESULTS[last_flush_idx:])
    header = not os.path.exists(INTERMEDIATE_OUT_CSV)
    leftover_df.to_csv(INTERMEDIATE_OUT_CSV, mode='a', header=header, index=False)
    print(f"Final intermediate flush: saved remaining {len(RESULTS) - last_flush_idx} rows.")
# Out:
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [5/163] done | elapsed ~4.0 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [10/163] done | elapsed ~8.0 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [15/163] done | elapsed ~11.9 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [20/163] done | elapsed ~15.8 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [25/163] done | elapsed ~19.8 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [30/163] done | elapsed ~23.7 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [35/163] done | elapsed ~27.6 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [40/163] done | elapsed ~31.6 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [45/163] done | elapsed ~35.5 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [50/163] done | elapsed ~39.4 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [55/163] done | elapsed ~43.4 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [60/163] done | elapsed ~47.3 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [65/163] done | elapsed ~51.2 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [70/163] done | elapsed ~55.2 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [75/163] done | elapsed ~59.1 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [80/163] done | elapsed ~63.2 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [85/163] done | elapsed ~67.2 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [90/163] done | elapsed ~71.2 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [95/163] done | elapsed ~75.1 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [100/163] done | elapsed ~79.0 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [105/163] done | elapsed ~83.0 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [110/163] done | elapsed ~86.9 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [130/163] done | elapsed ~102.7 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [135/163] done | elapsed ~106.7 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [140/163] done | elapsed ~110.6 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [145/163] done | elapsed ~114.6 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [150/163] done | elapsed ~118.5 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [155/163] done | elapsed ~122.4 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [160/163] done | elapsed ~126.4 min
#   Intermediate results saved to /home/wangzn/projects/aip-vshwartz/wangzn/adapter_mllm/code_mixing_results/ur_eval_intermediate.csv
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Final intermediate flush: saved remaining 24 rows.

# %%
# ============================================================
# Save + summary (per-run file, safe for parallel jobs)
# ============================================================
from pathlib import Path
from datetime import datetime
import socket
import os

df = pd.DataFrame(RESULTS)

# Save results inside the project
RESULTS_DIR = PROJECT_ROOT / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Unique run ID: hostname + PID + timestamp
run_id = f"{socket.gethostname()}_{os.getpid()}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"
out_csv = RESULTS_DIR / f"ur_eval_{run_id}.csv"

df.to_csv(out_csv, index=False)
print("\n✅ Saved per-input results:", out_csv)

summary = (
    df.groupby("system")["ppl"]
      .mean()
      .reset_index()
      .sort_values("ppl")
)

print("\n=== Avg PPL per system ===")
display(summary)

df.head()
